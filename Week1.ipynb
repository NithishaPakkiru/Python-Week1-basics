# %%
## printing the Hello World program

print("Hello World")
# Out:
# Hello World

# %%
## Assigning name to a variable

name = "Nithisha"
name
# Out:
# 'Nithisha'

# %%
age = 26
age
# Out:
# 26

# %%
city = "Hyderabad"
city
# Out:
# 'Hyderabad'

# %%
## Assigning values to different variables

X = 3
Y = 5

# %%
## performing addition operation

X+Y
# Out:
# 8

# %%
## performing subtraction operation

X-Y
# Out:
# -2

# %%
## performing modulo operation which gives reminder by dividing X and Y
X%Y
# Out:
# 3

# %%
## performing division operation

X/Y
# Out:
# 0.6

# %%
## creating a list of food items and assigning to a variable

food = ["Biryani", "ChickenFry", "PaneerMasala", "Pasta"]

# %%
# checking the first value of the list

food[0]
# Out:
# 'Biryani'

# %%
# displaying the 2nd value from right

food[-3]
# Out:
# 'ChickenFry'

# %%
# displaying the last value 

food[-1]
# Out:
# 'Pasta'

# %%
## displaying the first 3 values

food[:3]
# Out:
# ['Biryani', 'ChickenFry', 'PaneerMasala']

# %%
# displaying all the values of the list excluding 1st value by considering index 1   

food[1:]
# Out:
# ['ChickenFry', 'PaneerMasala', 'Pasta']

# %%
food[1:3]
# Out:
# ['ChickenFry', 'PaneerMasala']

# %%
## assigning string values to a variable

Biodata = name,age,city
Biodata
# Out:
# ('Nithisha', 26, 'Hyderabad')

# %%
## asking the input from user and generating output based on it 

name = input("What is your name?")
age = input("How Old are you?")
hobby = input("What is your hobby?")
print("Hi " +  name  +  " It's nice meeting you! " + " Hey you are "  +  age  + " years old and your hobby is "  + hobby + ". Wow that's great! ")
# Out:
# What is your name?Nithisha
# How Old are you?26
# What is your hobby?Cooking
# Hi Nithisha It's nice meeting you!  Hey you are 26 years old and your hobby is Cooking. Wow that's great!
